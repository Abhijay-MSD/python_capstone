# %%
a=0
print('which harry potter character are you ?')
print("answer these 6 questions \n choose a,b,c,d or e. points are added to your account")
q1=input('which pet would you choose ? \n A. cat \n B. owl \n C. either a rat or toad \n C. pymgy puff \n D. any of the above \n ')
if (q1=='a'):
    a=a+40
    print('you have ', a , ' points in your acccount')
elif (q1=='b'):
    a=a+50
    print('you have ', a , ' points in your acccount')
elif (q1=='c'):
    a=a+20
    print('you have ', a , ' points in your acccount')
elif (q1=='d'):
    a=a+30
    print('you have ', a , ' points in your acccount')
elif (q1 =='e'):
    a=a+10
    print('you have ', a , ' points in your acccount')
else:
    print('invalid !!')
q2=input('how would your friends describe you? \n A. a leader \n B. sarcastic and funny \n C. smart and talented \n D. eccentric \n E. self confident \n')
if (q2=='a'):
    a=a+50
    print('you have ', a , ' points in your acccount')
elif (q2=='b'):
    a=a+20
    print('you have ', a , ' points in your acccount')
elif (q2=='c'):
    a=a+40
    print('you have ', a , ' points in your acccount')
elif (q2=='d'):
    a=a+10
    print('you have ', a , ' points in your acccount')
elif (q2=='e'):
    a=a+30
    print('you have ', a , ' points in your acccount')
else:
    print('invalid !!')
q3=input('who is your favourite professer? \n A. severus \n B. horace \n C. remus \n D. albus \n E. minerva \n ')
if (q3=='a'):
    a=a+30
    print('you have ', a , ' points in your acccount')
elif (q3=='b'):
    a=a+20
    print('you have ', a , ' points in your acccount')
elif (q3=='c'):
    a=a+40
    print('you have ', a , ' points in your acccount')
elif (q3=='d'):
    a=a+50
    print('you have ', a , ' points in your acccount')
elif (q3=='e'):
    a=a+10
    print('you have ', a , ' points in your acccount')
else:
    print('invalid !!')
q4=input('what subject is your favourite? \n A. potions \n B. defense against the dark arts \n C. charms \n D. all \n E. none \n ')
if (q4=='a'):
    a=a+30
    print('you have ', a , ' points in your acccount')
elif (q4=='b'):
    a=a+50
    print('you have ', a , ' points in your acccount')
elif (q4=='c'):
    a=a+10
    print('you have ', a , ' points in your acccount')
elif (q4=='d'):
    a=a+40
    print('you have ', a , ' points in your acccount')
elif (q4=='e'):
    a=a+20
    print('you have ', a , ' points in your acccount')
else:
    print('invalid !!')
q5=input('what kind of people do you like most? \n A. like me \n B. smart \n C. brave \n D. funny \n E. unique \n')
if (q5=='a'):
    a=a+20
    print('you have ', a , ' points in your acccount')
elif (q5=='b'):
    a=a+30
    print('you have ', a , ' points in your acccount')
elif (q5=='c'):
    a=a+50
    print('you have ', a , ' points in your acccount')
elif (q5=='d'):
    a=a+40
    print('you have ', a , ' points in your acccount')
elif (q5=='e'):
    a=a+10
    print('you have ', a , ' points in your acccount')
else:
    print('invalid !!')
q6=input('Who do you like the most? \n A. harry \n B. ginny or ron \n C. hermione \n D. luna \n E. neville \n')
if (q6=='a'):
    a=a+40
    print('you have ', a , ' points in your acccount')
elif (q6=='b'):
    a=a+50
    print('you have ', a , ' points in your acccount')
elif (q6=='c'):
    a=a+30
    print('you have ', a , ' points in your acccount')
elif (q6=='d'):
    a=a+20
    print('you have ', a , ' points in your acccount')
elif (q6=='e'):
    a=a+10
    print('you have ', a , ' points in your acccount')
else:
    print('invalid !!')
print('now you have finished the test let us see the result \n')
if (60<a<90):
    print ('>>> you are luna lovegood')
elif (100<a<120):
    print('>>> you are neville longbottom')
elif (130<a<160):
    print('>>> you are ron weasly')
elif (170<a<200):
    print('>>> you are ginny weasly')
elif (210<a<250):
    print('>>> you are hermione granger')
elif (260<a<300):
    print('>>> you are harry potter')
else:
    print('something went wrong, sorry.')
